# %%
import ROOT as r
from utils.file import CvvarReader

# %%
reader_20230713_per0002 = CvvarReader('/analysis/hamada_msgc/20230713/per0002/cvvar.root')
reader_20230720_per0003 = CvvarReader('/analysis/hamada_msgc/20230720/per0003/cvvar.root')
# Out:
# Warning in <TFile::Init>: file /analysis/hamada_msgc/20230713/per0002/cvvar.root probably not closed, trying to recover
# Info in <TFile::Recover>: /analysis/hamada_msgc/20230713/per0002/cvvar.root, recovered key TTree:cvvar_tree at address 9081391
# Warning in <TFile::Init>: successfully recovered 1 keys
# Warning in <TFile::Init>: no StreamerInfo found in /analysis/hamada_msgc/20230713/per0002/cvvar.root therefore preventing schema evolution when reading this file. The file was produced with version 6.26/10 of ROOT.

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230713_per0002.hist('ene_anode_sum:ene_cathode_sum', '200, 0, 1000, 200, 0, 1000', cut_contidion='')
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230720_per0003.hist('ene_anode_sum:ene_cathode_sum', '200, 0, 1000, 200, 0, 1000', cut_contidion='')
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230720_per0003.hist('ene_anode_sum', '200, 0, 1000', cut_contidion='')
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230720_per0003.hist('ene_cathode_sum', '200, 0, 1000', cut_contidion='')
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230720_per0003.hist('z_yz:y_yz', '300, -16, 16, 300, -20, 30', cut_contidion='')
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas("", "", 500, 500)
h = reader_20230720_per0003.hist('z_xz:x_xz', '300, -16, 16, 300, -20, 30', cut_contidion='')
h.Draw("colz")
c.Draw()
